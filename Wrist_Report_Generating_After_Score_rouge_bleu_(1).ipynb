# %% [markdown]
# <a href="https://colab.research.google.com/github/sumanlaraee/fyp_Genrative_AI_LLMS_IDEFICS/blob/main/Wrist_Report_Generating_After_Score_rouge_bleu_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install rouge-score nltk
# Out:
# Collecting rouge-score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.25.2)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.4)
# Building wheels for collected packages: rouge-score
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24933 sha256=3a5bba8747c43be69858951a663301447e0243237ee649d8f76e96fbd25f7774
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge-score
# Installing collected packages: rouge-score
# Successfully installed rouge-score-0.1.2

# %%
# !pip install -q datasets
# !pip install -q git+https://github.com/huggingface/transformers.git
# !pip install -q bitsandbytes sentencepiece accelerate loralib
# !pip install -q -U git+https://github.com/huggingface/peft.git
# !pip install -i https://pypi.org/simple/ bitsandbytes
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.1/542.1 kB 4.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 7.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 7.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 6.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.31.0, but you have requests 2.32.3 which is incompatible.
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for transformers (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 MB 8.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.6/302.6 kB 35.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 48.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for peft (pyproject.toml) ... done
# Looking in indexes: https://pypi.org/simple/
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.10/dist-packages (0.43.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from bitsandbytes) (2.3.0+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bitsandbytes) (1.25.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (4.12.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->bitsandbytes) (12.5.40)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->bitsandbytes) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->bitsandbytes) (1.3.0)

# %%
# !pip install --upgrade transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.42.0.dev0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.14.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.23.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (4.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.6.2)

# %%
import torch
from datasets import load_dataset
from peft import LoraConfig, get_peft_model
from PIL import Image
from transformers import IdeficsForVisionText2Text, AutoProcessor, Trainer, TrainingArguments, BitsAndBytesConfig
import torchvision.transforms as transforms
import pandas as pd
from rouge_score import rouge_scorer
import nltk
from nltk.translate.bleu_score import sentence_bleu

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
checkpoint = "HuggingFaceM4/idefics-9b"
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16,
    llm_int8_skip_modules=["lm_head", "embed_tokens"],
)

# %%
processor = AutoProcessor.from_pretrained(checkpoint)
model = IdeficsForVisionText2Text.from_pretrained(checkpoint, quantization_config=bnb_config, device_map="auto")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/281 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.36k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/61.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/181 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# config.json:   0%|          | 0.00/1.41k [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/99.2k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/19 [00:00<?, ?it/s]
# model-00001-of-00019.safetensors:   0%|          | 0.00/2.00G [00:00<?, ?B/s]
# model-00002-of-00019.safetensors:   0%|          | 0.00/1.82G [00:00<?, ?B/s]
# model-00003-of-00019.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00004-of-00019.safetensors:   0%|          | 0.00/1.93G [00:00<?, ?B/s]
# model-00005-of-00019.safetensors:   0%|          | 0.00/1.93G [00:00<?, ?B/s]
# model-00006-of-00019.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00007-of-00019.safetensors:   0%|          | 0.00/1.89G [00:00<?, ?B/s]
# model-00008-of-00019.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00009-of-00019.safetensors:   0%|          | 0.00/1.93G [00:00<?, ?B/s]
# model-00010-of-00019.safetensors:   0%|          | 0.00/1.93G [00:00<?, ?B/s]
# model-00011-of-00019.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00012-of-00019.safetensors:   0%|          | 0.00/1.89G [00:00<?, ?B/s]
# model-00013-of-00019.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00014-of-00019.safetensors:   0%|          | 0.00/1.93G [00:00<?, ?B/s]
# model-00015-of-00019.safetensors:   0%|          | 0.00/1.93G [00:00<?, ?B/s]
# model-00016-of-00019.safetensors:   0%|          | 0.00/1.97G [00:00<?, ?B/s]
# model-00017-of-00019.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00018-of-00019.safetensors:   0%|          | 0.00/1.97G [00:00<?, ?B/s]
# model-00019-of-00019.safetensors:   0%|          | 0.00/705M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/19 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]

# %%
def do_inference(model, processor, prompt, max_new_tokens=150):
    tokenizer = processor.tokenizer
    bad_words = ["", "<fake_token_around_image>"]
    if len(bad_words) > 0:
        bad_words_ids = tokenizer(bad_words, add_special_tokens=False).input_ids
    eos_token = "</s>"
    eos_token_id = tokenizer.convert_tokens_to_ids(eos_token)

    input = processor(prompt, return_tensors="pt").to(device)
    generated_ids = model.generate(
        **input,
        eos_token_id=[eos_token_id],
        bad_words_ids=bad_words_ids,
        max_new_tokens=max_new_tokens,
        early_stopping=True)
    generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]
    print(generated_text)
    return generated_text

# %%
from peft import get_peft_model, LoraConfig, TaskType, prepare_model_for_kbit_training

model.gradient_checkpointing_enable()
model = prepare_model_for_kbit_training(model)

# %%
peft_config = LoraConfig(
    r=16,
    lora_alpha=32,
    target_modules=["q_proj", "k_proj", "v_proj"],
    lora_dropout=0.05,
    bias="none"
)

# %%
model = get_peft_model(model, peft_config)

alpaca_prompt = """Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.

### Instruction:
{}

### Input:
{}

### Response:
{}"""

# %%
from transformers import AutoTokenizer, AutoModel
tokenizer = AutoTokenizer.from_pretrained(checkpoint, padding_side="right",)
tokenizer.pad_token = tokenizer.eos_token
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
tokenizer.pad_token = tokenizer.eos_token
EOS_TOKEN = tokenizer.eos_token

def format_dataset(examples):
    image_name = examples['image_name']
    prompt = alpaca_prompt.format(examples["instructions"], f"{examples['inputs']}\nhttps://github.com/GoutamSachdev/ReportDataSet/blob/main/Images/{image_name}?raw=true", examples["outputs"]) + EOS_TOKEN
    tokens = tokenizer(prompt, truncation=True, max_length=256, padding="max_length",)
    tokens["labels"] = tokens['input_ids'].copy()
    return tokens

# %%
dataset = load_dataset('csv', data_files='/content/format Report.csv', split="train")
dataset = dataset.map(format_dataset)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/618 [00:00<?, ? examples/s]

# %%
def convert_to_rgb(image_path):
    image = Image.open(image_path)
    if image.mode == "RGB":
        return image
    image_rgba = image.convert("RGBA")
    background = Image.new("RGBA", image_rgba.size, (255, 255, 255))
    alpha_composite = Image.alpha_composite(background, image_rgba)
    return alpha_composite.convert("RGB")

# %%
def tmp_transforms(examples):
    image_size = processor.image_processor.image_size
    image_mean = processor.image_processor.image_mean
    image_std = processor.image_processor.image_std
    image_transform = transforms.Compose([
        convert_to_rgb,
        transforms.RandomResizedCrop((image_size, image_size), scale=(0.9, 1.0), interpolation=transforms.InterpolationMode.BICUBIC),
        transforms.ToTensor(),
        transforms.Normalize(mean=image_mean, std=image_std)
    ])
    prompts = []
    for i in range(len(examples['instructions'])):
        img = examples['image_name'][i]
        text = alpaca_prompt.format(examples["instructions"], f"""{examples["inputs"]}\nhttps://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/{img}?raw=true""", examples["outputs"]) + EOS_TOKEN
        prompts.append(text)
    inputs = processor(prompts, transform=image_transform, return_tensors="pt").to(device)
    inputs["labels"] = inputs["input_ids"]
    return inputs

# %%
tmp = dataset.train_test_split(test_size=0.3)
train_dataset = tmp["train"]
test_dataset = tmp["test"]
train_dataset.set_transform(tmp_transforms)
test_dataset.set_transform(tmp_transforms)

# %%
print(tokenizer.decode(train_dataset[0]['input_ids']))
import torch
if torch.cuda.device_count() > 1:
    model.is_parallelizable = True
    model.model_parallel = True
# Out:
# <s> Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.
#
# ### Instruction:
# ['Based on the analysis of Wrist Xray, the following issues have been identified:']
#
# ### Input:
# ["['toxt', 'pronotoraios', 'fractune']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/3369_1184055429_01_WRI-L2_M011.png?raw=true
#
# ### Response:
# ['There is evidence of fracture identified in the left distal radius .Normal joint spaces.. Soft tissue swelling noted.. Wrist Xray is Fracture']</s>

# %%
def evaluate_model(model, processor, test_dataset):
    predictions = []
    references = []
    for example in test_dataset:
        prompt = tokenizer.decode(example['input_ids'], skip_special_tokens=True)
        generated_text = do_inference(model, processor, prompt)
        predictions.append(generated_text)
        references.append(tokenizer.decode(example['labels'], skip_special_tokens=True))

    scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
    rouge_scores = {'rouge1': 0, 'rouge2': 0, 'rougeL': 0}
    bleu_scores = []

    for ref, pred in zip(references, predictions):
        rouge = scorer.score(ref, pred)
        for key in rouge_scores:
            rouge_scores[key] += rouge[key].fmeasure

        bleu_scores.append(sentence_bleu([ref.split()], pred.split()))

    rouge_scores = {key: value / len(references) for key, value in rouge_scores.items()}
    avg_bleu_score = sum(bleu_scores) / len(bleu_scores)

    return rouge_scores, avg_bleu_score

# Evaluate before training
pre_train_rouge, pre_train_bleu = evaluate_model(model, processor, test_dataset)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:588: UserWarning: `num_beams` is set to 1. However, `early_stopping` is set to `True` -- this flag is only used in beam-based generation modes. You should set `num_beams>1` or unset `early_stopping`.
#   warnings.warn(
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['pronatoraign','text','r']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/3331_0913624270_01_WRI-R2_M011.png?raw=true
#
# ###Response:
# ['Thereisnoevidenceoffractureorbonyabnormalities..Thereisnoevidenceoffractureorbonyabnormalties.Normaljointspaces.Nomralsofttissuedensities..WristXrayisNormal']
#
# The above example is a simple example of a dialogue between a doctor and a patient. The doctor is asking the patient to describe the condition of his wrist. The patient is responding to the doctor’s question. The doctor is asking the patient to describe the condition of his wrist. The patient is responding to the doctor’s question. The doctor is asking the patient to describe the condition of his wrist. The patient is responding to the doctor’s question. The doctor is asking the patient to describe the condition of his wrist. The patient is responding to the doctor’s question. The doctor is asking the patient to describe the condition of his wrist. The patient is responding to the
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['periostealreaction','ture','ra','fracturs','pernostealreoctioc','text','r']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0657_0603279340_05_WRI-R1_M004.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffracturessidentifiedintherightdistalradius&ulna.Normaljointspaces.\nSofttissueswellingnoted\n.WristXrayisFracture']
#
# The above example is a simple example of a dialogue between a human and a chatbot. The chatbot is able to understand the human’s request and respond accordingly.
#
# The chatbot is able to understand the human’s request and respond accordingly.
#
# The chatbot is able to understand the human’s request and respond accordingly.
#
# The chatbot is able to understand the human’s request and respond accordingly.
#
# The chatbot is able to understand the human’s request and respond accordingly.
#
# The chatbot is able to understand the human’s request and respond accordingly.
#
# The chatbot is able to understand the human’s request and respond accordingly.
#
# The chatbot
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['s']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0051_0629216892_03_WRI-R1_M017.png?raw=true
#
# ###Response:
# ['Thereisnoevidenceoffractureorbonyabnormalities.Normaljointspaces.Normalsofttissuedensities..WristXrayisNormal']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0051_0629216892_03_WRI-R1_M017.png?raw=true
#
# The following is a list of the most common errors in the use of the word “that”:
#
# The following is a list of the most common errors in the use of the word “that”:
#
# The following is a list of the most common errors in the use of the word “that”:
#
# The following is a list of the most common errors in the use of the word “that”:
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','r','perostealreaction','fracture','periosteall','soction','ext','s']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0520_0503898806_04_WRI-R1_F009.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffractureidentifiedintherightdistalradius.Normaljointspaces.\nSofttissueswellingnoted\n.WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0520_0503898806_04_WRI-R1_F009.png?raw=true
#
# The following is a list of the most common errors in the use of the word “fracture”:
#
# The following is a list of the most common errors in the use of the word “fracture”:
#
# The following is a list of the most common errors in the use of the word “fracture”:
#
# The following is a list of the most common errors in the use of
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['pronatorsign','tractu','text','r']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0764_0286535673_01_WRI-R2_M014.png?raw=true
#
# ###Response:
# ['.Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0764_0286535673_01_WRI-R2_M014.png?raw=true
#
# The above example is a simple example of a conversation between two people. The first person is asking the second person to do something. The second person is responding to the first person. The first person is asking the second person to do something. The second person is responding to the first person. The first person is asking the second person to do something. The second person is responding to the first person. The first person
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','fracture','pronoloraign','lroou']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/4181_1049609915_01_WRI-L2_M009.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffractureidentifiedintheleftdistalulna.Normaljointspaces..Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/4181_1049609915_01_WRI-L2_M009.png?raw=true
#
# The above example is a simple example of how to use the NLP module in Python.
#
# The NLP module is a Python library that provides a set of tools for natural language processing. It is a Python library that is used to perform natural language processing tasks. It is a Python library that is used to perform natural language processing tasks. It is a Python library that is used to perform natural language processing tasks. It is
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['pronatorsign','roos','to','text','r']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/3683_1195946281_01_WRI-R2_F012.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffractureidentifiedintherightdistalradius.Normaljointspaces..Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/3683_1195946281_01_WRI-R2_F012.png?raw=true
#
# The following is a list of the most common errors in the use of the word “that”:
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
#
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','fracturet','fracture']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0262_0499782262_01_WRI-L1_F011.png?raw=true
#
# ###Response:
# ['Thereisevidenceoftorusfractureidentifiedintheleftdistalradius.Normaljointspaces..Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0262_0499782262_01_WRI-L1_F011.png?raw=true
#
# The following is a list of the most common errors in the use of the word “fracture”:
#
# The following is a list of the most common errors in the use of the word “fracture”:
#
# The following is a list of the most common errors in the use of the word “fracture”:
#
# The following is a list of the most common errors in the use of
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['fractunt','toxt']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/1190_0882356298_01_WRI-L1_M012.png?raw=true
#
# ###Response:
# ['.Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/1190_0882356298_01_WRI-L1_M012.png?raw=true
#
# The above example is a simple example of a conversation between two people. The first person is asking the second person to do something. The second person is responding to the first person. The first person is asking the second person to do something. The second person is responding to the first person. The first person is asking the second person to do something. The second person is responding to the first person. The first person
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','r','fracture','pronatorsign','tractuns']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0129_1035715705_01_WRI-R2_F011.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffracturesidentifiedintherightdistal34ofradius&ulna.Normaljointspaces.\nSofttissueswellingnoted.\n.WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0129_1035715705_01_WRI-R2_F011.png?raw=true
#
# ###Output:
# ['Thereisevidenceoffracturesidentifiedintherightdistal34ofradius&ulna.Normaljointspaces.Softtissueswellingnoted.WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0129_1035
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','periosteolreaction','fro','cturt']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0455_1150226290_01_WRI-L2_M008.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffracturesidentifiedinthelefttdistalradius.Normaljointspaces..Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0455_1150226290_01_WRI-L2_M008.png?raw=true
#
# The following is a list of the most common errors in the use of the word “that”:
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
#
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['toxt','r','periostealreaction','fractu','ung']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/1363_1148111366_01_WRI-R2_F007.png?raw=true
#
# ###Response:
# ['.Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/1363_1148111366_01_WRI-R2_F007.png?raw=true
#
# The above example is a simple example of how the model can be used to generate a response. The model is trained on a set of images and the model is able to generate a response that is similar to the training data. The model is able to generate a response that is similar to the training data. The model is able to generate a response that is similar to the training data. The model is able to generate a response that
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','tracture','rocune']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0017_1043285078_01_WRI-L2_F001.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffracturesidentifiedintheleftmidshaftsofradiusulna.\nNormaljointspaces.\n.Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0017_1043285078_01_WRI-L2_F001.png?raw=true
#
# The following is a list of the most common errors in the use of the word “that”:
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
#
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['softtissue','ext']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0023_0657842010_02_WRI-L2_M012.png?raw=true
#
# ###Response:
# ['Thereisnoevidenceoffractureorbonyabnormalities.Normaljointspaces.Normalsofttissuedensities..WristXrayisNormal']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0023_0657842010_02_WRI-L2_M012.png?raw=true
#
# The above example is a simple example of a conversation between two people. The first person is asking the second person to do something. The second person is responding to the first person. The first person is asking the second person to do something. The second person is responding to the first person. The first person is asking the second person to do something. The second person is responding to the first person. The first person
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['pronatorsign','text','fracture']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/3218_0625798464_01_WRI-L2_F006.png?raw=true
#
# ###Response:
# ['Thereisevidenceoftorusfractureidentifiedintherightdistalradius&ulna.Normaljointspaces..Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/3218_0625798464_01_WRI-L2_F006.png?raw=true
#
# The following is a list of the most common errors in the use of the word “that”:
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
#
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['fracture','periostealreaction','text','e']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/5701_0909307380_02_WRI-R2_F010.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffractureidentifiedintherightdistalradius.Normaljointspaces..Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/
action']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0285_0936410060_02_WRI-L2_M014.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffractureidentifiedintheleftdistalradius&ulnarstyloidprocess.Normaljointspaces..Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0285_0936410060_02_WRI-L2_M014.png?raw=true
#
# The following is a list of the most common errors in the use of the word “fracture”:
#
# The following is a list of the most common errors in the use of the word “fracture”:
#
# The following is a list of the most common errors in the use of the word “fracture”:
#
# The following is a list of the most common errors in the use of
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['fracture','tons','r']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/1316_0726631683_01_WRI-R2_M013.png?raw=true
#
# ###Response:
# ['.Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/1316_0726631683_01_WRI-R2_M013.png?raw=true
#
# The above example is a simple example of a conversation between two people. The first person is asking the second person to do something. The second person is responding to the first person. The first person is asking the second person to do something. The second person is responding to the first person. The first person is asking the second person to do something. The second person is responding to the first person. The first person
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['fracturet','peniostealreaction','ext']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0378_0759433213_05_WRI-L2_F013.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffracturewithinternalfixation&nailingidentifiedintheleftdistalradius..Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0378_0759433213_05_WRI-L2_F013.png?raw=true
#
# The above example is a simple example of how to use the NLP module in Python.
#
# The NLP module is a Python library that provides a set of tools for natural language processing. It is a Python library that is used to perform natural language processing tasks. It is a Python library that is used to perform natural language processing tasks. It is a Python library that is used to perform natural language processing tasks. It is
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ...
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ['[]']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0024_0210292654_01_WRI-L1_M011.png?raw=true
#
# ###Response:
# ['Thereisnoevidenceoffractureorbonyabnormalities..Normaljointspaces.\nNormalsofttissuedensities.\n.WristXrayisNormal']
#
# The following is a list of the most common errors in the use of the word “is”:
#
# The following is a list of the most common errors in the use of the word “is”:
#
# The following is a list of the most common errors in the use of the word “is”:
#
# The following is a list of the most common errors in the use of the word “is”:
#
# The following is a list of the most common errors in the use of the word “is”:
#
# The following is a list of the most common errors in the use of the word “is”:
#
# The following is a list of the most common errors in the use of the word
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','text','bofttissue','pdnotorign','fratture']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/5688_0974138691_01_WRI-L2_M013.png?raw=true
#
# ###Response:
# ['Thereisevidenceoftorusfractureidentifiedintheleftdistalradius.Normaljointspaces..Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/5688_0974138691_01_WRI-L2_M013.png?raw=true
#
# The following is a list of the most common errors in the use of the word “that”:
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
#
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','r','fracturt','fracturt','fracturt','periosteolreaction']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/1165_0308843951_05_WRI-R1_M010.png?raw=true
#
# ###Response:
# ['.Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/1165_0308843951_05_WRI-R1_M010.png?raw=true
#
# The following is a list of the most common errors in the use of the NLP tool:
#
# The following is a list of the most common errors in the use of the NLP tool:
#
# The following is a list of the most common errors in the use of the NLP tool:
#
# The following is a list of the most common errors in the use of the NLP tool:
#
# The following
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['tonotorsign','fracture','tens']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/3744_1181170201_01_WRI-L2_M009.png?raw=true
#
# ###Response:
# ['Thereisevidenceoftorusfractureidentifiedintheleftdistalradius.Normaljointspaces..Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/3744_1181170201_01_WRI-L2_M009.png?raw=true
#
# The above example is a simple example of how to use the NLP module in Python.
#
# The NLP module is a Python library that provides a set of tools for natural language processing. It is a Python library that is used to perform natural language processing tasks. It is a Python library that is used to perform natural language processing tasks. It is a Python library that is used to perform natural language processing tasks. It is
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['pronatorsign','fracture','Left']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0015_0668695209_01_WRI-L2_F008.png?raw=true
#
# ###Response:
# ['Thereisevidenceoftorusfractureidentifiedinthedistalleftradius.\nNormaljointspaces\n.Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0015_0668695209_01_WRI-L2_F008.png?raw=true
#
# The following is a list of the most common errors in the use of the word “that”:
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
#
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','pronclorsign','fractunt']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/3827_1094412221_01_WRI-L2_F009.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffractureidentifiedintheleftdistalradiusmetaphysis.Normaljointspaces..Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/3827_1094412221_01_WRI-L2_F009.png?raw=true
#
# The following is a list of the most common errors in the use of the word “fracture”:
#
# The following is a list of the most common errors in the use of the word “fracture”:
#
# The following is a list of the most common errors in the use of the word “fracture”:
#
# The following is a list of the most common errors in the use of
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','softtissue','fracture']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0512_0715171684_01_WRI-L2_F010.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffractureidentifiedintheleftdistalradius.Normaljointspaces.Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0512_0715171684_01_WRI-L2_F010.png?raw=true
#
# The following is a list of the most common errors in the use of the word “that”:
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
#
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['fractuns','periostealreoction','text']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0261_0727351664_03_WRI-L2_M011.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffractureidentifiedintheleftdistalradiusmetaphysis.Normaljointspaces..Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0261_0727351664_03_WRI-L2_M011.png?raw=true
#
# The following is a list of the most common errors in the use of the word “fracture”:
#
# The following is a list of the most common errors in the use of the word “fracture”:
#
# The following is a list of the most common errors in the use of the word “fracture”:
#
# The following is a list of the most common errors in the use of
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','ri','pronolorsign','fracture']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/4170_1007637127_01_WRI-R2_F015.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffractureidentifiedintherightdistalradiusmetaphysis.Normaljointspaces..Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/4170_1007637127_01_WRI-R2_F015.png?raw=true
#
# The following is a list of the most common errors in the use of the word “that”:
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
#
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','pronatorsign','fracturs','fractuns']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/3108_1060434691_01_WRI-L2_M015.png?raw=true
#
# ###Response:
# ['Thereisevidenceoftorusfractureidentifiedintheleftdistalradius.Normaljointspaces..Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/3108_1060434691_01_WRI-L2_M015.png?raw=true
#
# The following is a list of the most common errors in the use of the word “fracture”:
#
# The word “fracture” is used in the following contexts:
#
# The word “fracture” is used in the following contexts:
#
# The word “fracture” is used in the following contexts:
#
# The word “fracture” is used in the
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['softtissuc','fra','sture','text','l']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0877_0700504386_01_WRI-L2_M016.png?raw=true
#
# ###Response:
# ['.Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0877_0700504386_01_WRI-L2_M016.png?raw=true
#
# The above example is a simple example of a conversation between two people. The first person is asking the second person to do something. The second person is responding to the first person. The first person is asking the second person to do something. The second person is responding to the first person. The first person is asking the second person to do something. The second person is responding to the first person. The first person
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['fracture','text','a']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0332_0254991689_01_WRI-R1_F008.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffractureidentifiedintherightdistalradius.Normaljointspaces..Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0332_0254991689_01_WRI-R1_F008.png?raw=true
#
# The above example is a simple example of a conversation between two people. The first person is asking the second person to do something. The second person is responding to the first person. The first person is asking the second person to do something. The second person is responding to the first person. The first person is asking the second person to do something. The second person is responding to the first person. The first person
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','r','fracture']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0407_1246666978_01_WRI-R1_F008.png?raw=true
#
# ###Response:
# ['Thereisevidenceoftorusfracturesidentifiedintherightdistalradius&ulna.Normaljointspaces..Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0407_1246666978_01_WRI-R1_F008.png?raw=true
#
# The following is a list of the most common errors in the use of the word “that”:
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
#
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','r','pernostealreoction','fractun','fracturt']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/5858_1045226268_05_WRI-R1_M003.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffractureidentifiedintherightdistal3rdradius.Normaljointspaces..Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/5858_1045226268_05_WRI-R1_M003.png?raw=true
#
# The following is a list of the most common errors in the use of the word “fracture”:
#
# The following is a list of the most common errors in the use of the word “fracture”:
#
# The following is a list of the most common errors in the use of the word “fracture”:
#
# The following is a list of the most common errors in the use of
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['softtissue','text','l']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0198_0798640498_01_WRI-L2_M011.png?raw=true
#
# ###Response:
# ['Thereisnoevidenceoffractureorbonyabnormalities..Normalsofttissuedensities..WristXrayisNormal']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0198_0798640498_01_WRI-L2_M011.png?raw=true
#
# The above example is a simple example of a conversation between two people. The first person is asking the second person to do something. The second person is responding to the first person. The first person is asking the second person to do something. The second person is responding to the first person. The first person is asking the second person to do something. The second person is responding to the first person. The first person
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)

# %%
training_args = TrainingArguments(
    output_dir=f"{checkpoint.split('/')[1]}-WristXray",
    learning_rate=2e-4,
    fp16=True,
    per_device_train_batch_size=2,
    per_device_eval_batch_size=2,
    gradient_accumulation_steps=8,
    dataloader_pin_memory=False,
    save_total_limit=3,
    evaluation_strategy="steps",
    save_strategy="steps",
    eval_steps=25,
    save_steps=50,
    max_steps=50,
    logging_steps=10,
    remove_unused_columns=False,
    push_to_hub=False,
    label_names=["input_ids", "labels", "attention_mask"],
    load_best_model_at_end=True,
    report_to="none",
    optim="paged_adamw_8bit"
)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1493: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(

# %%
from transformers import DataCollatorForLanguageModeling
data_collator = DataCollatorForLanguageModeling(tokenizer, mlm=False)
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    tokenizer=tokenizer,
    data_collator=data_collator,
)
# Out:
# max_steps is given, it will override any value given in num_train_epochs

# %%
trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:91: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`...
#     <div>
#
#       <progress value='13' max='50' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [13/50 05:04 < 17:04, 0.04 it/s, Epoch 0.44/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='50' max='50' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [50/50 27:01, Epoch 1/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>25</td>
#       <td>1.576500</td>
#       <td>1.566303</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.563800</td>
#       <td>1.566303</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=50, training_loss=1.578066062927246, metrics={'train_runtime': 1650.1007, 'train_samples_per_second': 0.485, 'train_steps_per_second': 0.03, 'total_flos': 1.1290277141546688e+16, 'train_loss': 1.578066062927246, 'epoch': 1.8518518518518519})

# %%
# Evaluate after training
post_train_rouge, post_train_bleu = evaluate_model(model, processor, test_dataset)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:588: UserWarning: `num_beams` is set to 1. However, `early_stopping` is set to `True` -- this flag is only used in beam-based generation modes. You should set `num_beams>1` or unset `early_stopping`.
#   warnings.warn(
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['pronatoraign','text','r']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/3331_0913624270_01_WRI-R2_M011.png?raw=true
#
# ###Response:
# ['Thereisnoevidenceoffractureorbonyabnormalities..Thereisnoevidenceoffractureorbonyabnormalties.Normaljointspaces.Nomralsofttissuedensities..WristXrayisNormal']
#
# The above example is a simple example of a dialogue between a doctor and a patient. The doctor is asking the patient to describe the condition of his wrist. The patient is responding to the doctor’s question. The doctor is asking the patient to describe the condition of his wrist. The patient is responding to the doctor’s question. The doctor is asking the patient to describe the condition of his wrist. The patient is responding to the doctor’s question. The doctor is asking the patient to describe the condition of his wrist. The patient is responding to the doctor’s question. The doctor is asking the patient to describe the condition of his wrist. The patient is responding to the
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['periostealreaction','ture','ra','fracturs','pernostealreoctioc','text','r']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0657_0603279340_05_WRI-R1_M004.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffracturessidentifiedintherightdistalradius&ulna.Normaljointspaces.\nSofttissueswellingnoted\n.WristXrayisFracture']
#
# The above example is a simple example of a dialogue between a human and a chatbot. The chatbot is able to understand the human’s request and respond accordingly.
#
# The chatbot is able to understand the human’s request and respond accordingly.
#
# The chatbot is able to understand the human’s request and respond accordingly.
#
# The chatbot is able to understand the human’s request and respond accordingly.
#
# The chatbot is able to understand the human’s request and respond accordingly.
#
# The chatbot is able to understand the human’s request and respond accordingly.
#
# The chatbot is able to understand the human’s request and respond accordingly.
#
# The chatbot
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['s']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0051_0629216892_03_WRI-R1_M017.png?raw=true
#
# ###Response:
# ['Thereisnoevidenceoffractureorbonyabnormalities.Normaljointspaces.Normalsofttissuedensities..WristXrayisNormal']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0051_0629216892_03_WRI-R1_M017.png?raw=true
#
# The following is a list of the most common errors in the use of the word “that”:
#
# The following is a list of the most common errors in the use of the word “that”:
#
# The following is a list of the most common errors in the use of the word “that”:
#
# The following is a list of the most common errors in the use of the word “that”:
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','r','perostealreaction','fracture','periosteall','soction','ext','s']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0520_0503898806_04_WRI-R1_F009.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffractureidentifiedintherightdistalradius.Normaljointspaces.\nSofttissueswellingnoted\n.WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0520_0503898806_04_WRI-R1_F009.png?raw=true
#
# The following is a list of the most common errors in the use of the word “fracture”:
#
# The following is a list of the most common errors in the use of the word “fracture”:
#
# The following is a list of the most common errors in the use of the word “fracture”:
#
# The following is a list of the most common errors in the use of
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['pronatorsign','tractu','text','r']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0764_0286535673_01_WRI-R2_M014.png?raw=true
#
# ###Response:
# ['.Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0764_0286535673_01_WRI-R2_M014.png?raw=true
#
# The above example is a simple example of a conversation between two people. The first person is asking the second person to do something. The second person is responding to the first person. The first person is asking the second person to do something. The second person is responding to the first person. The first person is asking the second person to do something. The second person is responding to the first person. The first person
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','fracture','pronoloraign','lroou']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/4181_1049609915_01_WRI-L2_M009.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffractureidentifiedintheleftdistalulna.Normaljointspaces..Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/4181_1049609915_01_WRI-L2_M009.png?raw=true
#
# The above example is a simple example of how to use the NLP module in Python.
#
# The NLP module is a Python library that provides a set of tools for natural language processing. It is a Python library that is used to perform natural language processing tasks. It is a Python library that is used to perform natural language processing tasks. It is a Python library that is used to perform natural language processing tasks. It is
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['pronatorsign','roos','to','text','r']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/3683_1195946281_01_WRI-R2_F012.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffractureidentifiedintherightdistalradius.Normaljointspaces..Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/3683_1195946281_01_WRI-R2_F012.png?raw=true
#
# The following is a list of the most common errors in the use of the word “that”:
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
#
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','fracturet','fracture']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0262_0499782262_01_WRI-L1_F011.png?raw=true
#
# ###Response:
# ['Thereisevidenceoftorusfractureidentifiedintheleftdistalradius.Normaljointspaces..Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0262_0499782262_01_WRI-L1_F011.png?raw=true
#
# The following is a list of the most common errors in the use of the word “fracture”:
#
# The following is a list of the most common errors in the use of the word “fracture”:
#
# The following is a list of the most common errors in the use of the word “fracture”:
#
# The following is a list of the most common errors in the use of
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['fractunt','toxt']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/1190_0882356298_01_WRI-L1_M012.png?raw=true
#
# ###Response:
# ['.Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/1190_0882356298_01_WRI-L1_M012.png?raw=true
#
# The above example is a simple example of a conversation between two people. The first person is asking the second person to do something. The second person is responding to the first person. The first person is asking the second person to do something. The second person is responding to the first person. The first person is asking the second person to do something. The second person is responding to the first person. The first person
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','r','fracture','pronatorsign','tractuns']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0129_1035715705_01_WRI-R2_F011.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffracturesidentifiedintherightdistal34ofradius&ulna.Normaljointspaces.\nSofttissueswellingnoted.\n.WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0129_1035715705_01_WRI-R2_F011.png?raw=true
#
# ###Output:
# ['Thereisevidenceoffracturesidentifiedintherightdistal34ofradius&ulna.Normaljointspaces.Softtissueswellingnoted.WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0129_1035
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','periosteolreaction','fro','cturt']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0455_1150226290_01_WRI-L2_M008.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffracturesidentifiedinthelefttdistalradius.Normaljointspaces..Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0455_1150226290_01_WRI-L2_M008.png?raw=true
#
# The following is a list of the most common errors in the use of the word “that”:
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
#
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['toxt','r','periostealreaction','fractu','ung']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/1363_1148111366_01_WRI-R2_F007.png?raw=true
#
# ###Response:
# ['.Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/1363_1148111366_01_WRI-R2_F007.png?raw=true
#
# The above example is a simple example of how the model can be used to generate a response. The model is trained on a set of images and the model is able to generate a response that is similar to the training data. The model is able to generate a response that is similar to the training data. The model is able to generate a response that is similar to the training data. The model is able to generate a response that
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','tracture','rocune']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0017_1043285078_01_WRI-L2_F001.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffracturesidentifiedintheleftmidshaftsofradiusulna.\nNormaljointspaces.\n.Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0017_1043285078_01_WRI-L2_F001.png?raw=true
#
# The following is a list of the most common errors in the use of the word “that”:
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
#
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['softtissue','ext']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0023_0657842010_02_WRI-L2_M012.png?raw=true
#
# ###Response:
# ['Thereisnoevidenceoffractureorbonyabnormalities.Normaljointspaces.Normalsofttissuedensities..WristXrayisNormal']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0023_0657842010_02_WRI-L2_M012.png?raw=true
#
# The above example is a simple example of a conversation between two people. The first person is asking the second person to do something. The second person is responding to the first person. The first person is asking the second person to do something. The second person is responding to the first person. The first person is asking the second person to do something. The second person is responding to the first person. The first person
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['pronatorsign','text','fracture']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/3218_0625798464_01_WRI-L2_F006.png?raw=true
#
# ###Response:
# ['Thereisevidenceoftorusfractureidentifiedintherightdistalradius&ulna.Normaljointspaces..Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/3218_0625798464_01_WRI-L2_F006.png?raw=true
#
# The following is a list of the most common errors in the use of the word “that”:
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
#
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['fracture','periostealreaction','text','e']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/5701_0909307380_02_WRI-R2_F010.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffractureidentifiedintherightdistalradius.Normaljointspaces..Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/5701_0909307380_02_WRI-R2_F010.png?raw=true
#
# The following is a list of the most common errors in the use of the NLP tool.
#
# The following is a list of the most common errors in the use of the NLP tool.
#
# The following is a list of the most common errors in the use of the NLP tool.
#
# The following is a list of the most common errors in the use of the NLP tool.
#
# The following
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['tore','pe','fractune','fracture','periostealreoction']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0203_1115775196_03_WRI-L1_M011.png?raw=true
#
# ###Response:
# ['.Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0203_1115775196_03_WRI-L1_M011.png?raw=true
#
# The above example is a simple example of a conversation between two people. The first person is asking the second person to do something. The second person is responding to the first person. The first person is asking the second person to do something. The second person is responding to the first person. The first person is asking the second person to do something. The second person is responding to the first person. The first person
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','r','pronatorsin','fractur']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/1009_1044044123_01_WRI-R2_M013.png?raw=true
#
# ###Response:
# ['.Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/1009_1044044123_01_WRI-R2_M013.png?raw=true
#
# The above example is a simple example of a conversation between two people. The first person is asking the second person to do something. The second person is responding to the first person. The first person is asking the second person to do something. The second person is responding to the first person. The first person is asking the second person to do something. The second person is responding to the first person. The first person
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['prongtoraign','juw','le','text','s']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0050_0619640860_01_WRI-R2_M011.png?raw=true
#
# ###Response:
# ['Thereisevidenceoftorusfractureidentifiedtintheleftdistalradius.Normaljointspaces.\nSofttissueswellingnoted.\n.WristXrayisFracture']
#
# The above example is a simple example of a dialogue between a human and a chatbot. The chatbot is able to understand the human’s intent and respond accordingly.
#
# The chatbot is able to understand the human’s intent and respond accordingly.
#
# The chatbot is able to understand the human’s intent and respond accordingly.
#
# The chatbot is able to understand the human’s intent and respond accordingly.
#
# The chatbot is able to understand the human’s intent and respond accordingly.
#
# The chatbot is able to understand the human’s intent and respond accordingly.
#
# The chatbot is able to understand the human’s intent and respond accordingly.
#
# The chatbot
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['r']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0018_1173779048_01_WRI-R2_M015.png?raw=true
#
# ###Response:
# ['Thereisnoevidenceoffractureorbonyabnormalities.\nNormaljointspaces\n.Normalsofttissuedensities..WristXrayisNormal']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0018_1173779048_01_WRI-R2_M015.png?raw=true
#
# ###Conclusion:
# ['Thereisnoevidenceoffractureorbonyabnormalities.Normaljointspaces.Normalsofttissuedensities.WristXrayisNormal']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0018_1173779048_01_
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['tore','pe','fractune','fracture','periostealreoction']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0203_1115775196_03_WRI-L1_M011.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffractureidentifiedintheleftdistal3"ofradius..Normaljointspaces.\nSofttissueswellingnoted\n.WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0203_1115775196_03_WRI-L1_M011.png?raw=true
#
# The following is a list of the most common errors in the use of the word “fracture”:
#
# The word “fracture” is used in the following contexts:
#
# The word “fracture” is used in the following contexts:
#
# The word “fracture” is used in the following contexts:
#
# The word “fracture” is used in the
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['softtisse','socissue','racture','fracture','text','r']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/1254_0771414248_01_WRI-R1_M009.png?raw=true
#
# ###Response:
# ['.Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/1254_0771414248_01_WRI-R1_M009.png?raw=true
#
# The above example is a simple example of how to use the NLP module in Python.
#
# The NLP module is a Python library that provides a set of tools for natural language processing. It is a Python library that is used to perform natural language processing tasks. It is a Python library that is used to perform natural language processing tasks. It is a Python library that is used to perform natural language processing tasks. It is
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','r','softissue','solorsign','ra','sts']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/1250_0872315138_01_WRI-R2_F011.png?raw=true
#
# ###Response:
# ['.Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/1250_0872315138_01_WRI-R2_F011.png?raw=true
#
# The above example is a simple example of how the model works. The model is able to detect the fracture in the wrist and also the soft tissue swelling. The model is able to detect the fracture in the wrist and also the soft tissue swelling. The model is able to detect the fracture in the wrist and also the soft tissue swelling. The model is able
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ['[]']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0043_1102352941_01_WRI-R1_M007.png?raw=true
#
# ###Response:
# ['Thereisevidenceoftorusfractureidentifiedintherightdistalradius..Normaljointspaces.\nSofttissueswellingnoted.\n.WristXrayisFracture']
#
# ###Output:
# ['Thereisevidenceoftorusfractureidentifiedintherightdistalradius..Normaljointspaces.\nSofttissueswellingnoted.\n.WristXrayisFracture']
#
# The above example is a simple example of a dialogue between a human and a chatbot. The chatbot is able to understand the human’s request and respond accordingly.
#
# The chatbot is able to understand the human’s request and respond accordingly.
#
# The chatbot is able to understand the human’s request and respond accordingly.
#
# The chatbot is able to understand the human’s request and respond accordingly.
#
# The chatbot is able
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['tracture','periostealcaction','penosteolreaction','text','r']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/6061_0604221784_03_WRI-R1_M009.png?raw=true
#
# ###Response:
# ['Thereisevidenceofdisplacedfracturesidentifiedintherightdistalradius.Normaljointspaces..Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/6061_0604221784_03_WRI-R1_M009.png?raw=true
#
# ###Conclusion:
# ['Thereisevidenceofdisplacedfracturesidentifiedintherightdistalradius.Normaljointspaces..Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/6061_06042
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','l','fracture']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0685_0422722138_01_WRI-L2_M006.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffractureidentifiedintheleftdistalradius.Normaljointspaces.\nSofttissueswellingnoted\n.WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/
png?raw=true
#
# ###Response:
# ['.Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/1165_0308843951_05_WRI-R1_M010.png?raw=true
#
# The following is a list of the most common errors in the use of the NLP tool:
#
# The following is a list of the most common errors in the use of the NLP tool:
#
# The following is a list of the most common errors in the use of the NLP tool:
#
# The following is a list of the most common errors in the use of the NLP tool:
#
# The following
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['tonotorsign','fracture','tens']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/3744_1181170201_01_WRI-L2_M009.png?raw=true
#
# ###Response:
# ['Thereisevidenceoftorusfractureidentifiedintheleftdistalradius.Normaljointspaces..Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/3744_1181170201_01_WRI-L2_M009.png?raw=true
#
# The above example is a simple example of how to use the NLP module in Python.
#
# The NLP module is a Python library that provides a set of tools for natural language processing. It is a Python library that is used to perform natural language processing tasks. It is a Python library that is used to perform natural language processing tasks. It is a Python library that is used to perform natural language processing tasks. It is
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['pronatorsign','fracture','Left']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0015_0668695209_01_WRI-L2_F008.png?raw=true
#
# ###Response:
# ['Thereisevidenceoftorusfractureidentifiedinthedistalleftradius.\nNormaljointspaces\n.Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0015_0668695209_01_WRI-L2_F008.png?raw=true
#
# The following is a list of the most common errors in the use of the word “that”:
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
#
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','pronclorsign','fractunt']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/3827_1094412221_01_WRI-L2_F009.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffractureidentifiedintheleftdistalradiusmetaphysis.Normaljointspaces..Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/3827_1094412221_01_WRI-L2_F009.png?raw=true
#
# The following is a list of the most common errors in the use of the word “fracture”:
#
# The following is a list of the most common errors in the use of the word “fracture”:
#
# The following is a list of the most common errors in the use of the word “fracture”:
#
# The following is a list of the most common errors in the use of
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','softtissue','fracture']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0512_0715171684_01_WRI-L2_F010.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffractureidentifiedintheleftdistalradius.Normaljointspaces.Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0512_0715171684_01_WRI-L2_F010.png?raw=true
#
# The following is a list of the most common errors in the use of the word “that”:
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
#
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['fractuns','periostealreoction','text']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0261_0727351664_03_WRI-L2_M011.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffractureidentifiedintheleftdistalradiusmetaphysis.Normaljointspaces..Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0261_0727351664_03_WRI-L2_M011.png?raw=true
#
# The following is a list of the most common errors in the use of the word “fracture”:
#
# The following is a list of the most common errors in the use of the word “fracture”:
#
# The following is a list of the most common errors in the use of the word “fracture”:
#
# The following is a list of the most common errors in the use of
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','ri','pronolorsign','fracture']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/4170_1007637127_01_WRI-R2_F015.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffractureidentifiedintherightdistalradiusmetaphysis.Normaljointspaces..Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/4170_1007637127_01_WRI-R2_F015.png?raw=true
#
# The following is a list of the most common errors in the use of the word “that”:
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
#
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','pronatorsign','fracturs','fractuns']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/3108_1060434691_01_WRI-L2_M015.png?raw=true
#
# ###Response:
# ['Thereisevidenceoftorusfractureidentifiedintheleftdistalradius.Normaljointspaces..Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/3108_1060434691_01_WRI-L2_M015.png?raw=true
#
# The following is a list of the most common errors in the use of the word “fracture”:
#
# The word “fracture” is used in the following contexts:
#
# The word “fracture” is used in the following contexts:
#
# The word “fracture” is used in the following contexts:
#
# The word “fracture” is used in the
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['softtissuc','fra','sture','text','l']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0877_0700504386_01_WRI-L2_M016.png?raw=true
#
# ###Response:
# ['.Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0877_0700504386_01_WRI-L2_M016.png?raw=true
#
# The above example is a simple example of a conversation between two people. The first person is asking the second person to do something. The second person is responding to the first person. The first person is asking the second person to do something. The second person is responding to the first person. The first person is asking the second person to do something. The second person is responding to the first person. The first person
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['fracture','text','a']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0332_0254991689_01_WRI-R1_F008.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffractureidentifiedintherightdistalradius.Normaljointspaces..Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0332_0254991689_01_WRI-R1_F008.png?raw=true
#
# The above example is a simple example of a conversation between two people. The first person is asking the second person to do something. The second person is responding to the first person. The first person is asking the second person to do something. The second person is responding to the first person. The first person is asking the second person to do something. The second person is responding to the first person. The first person
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','r','fracture']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0407_1246666978_01_WRI-R1_F008.png?raw=true
#
# ###Response:
# ['Thereisevidenceoftorusfracturesidentifiedintherightdistalradius&ulna.Normaljointspaces..Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0407_1246666978_01_WRI-R1_F008.png?raw=true
#
# The following is a list of the most common errors in the use of the word “that”:
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
# The word “that” is used to introduce a subordinate clause.
#
#
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','r','pernostealreoction','fractun','fracturt']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/5858_1045226268_05_WRI-R1_M003.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffractureidentifiedintherightdistal3rdradius.Normaljointspaces..Softtissueswellingnoted..WristXrayisFracture']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/5858_1045226268_05_WRI-R1_M003.png?raw=true
#
# The following is a list of the most common errors in the use of the word “fracture”:
#
# The following is a list of the most common errors in the use of the word “fracture”:
#
# The following is a list of the most common errors in the use of the word “fracture”:
#
# The following is a list of the most common errors in the use of
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['softtissue','text','l']"]
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0198_0798640498_01_WRI-L2_M011.png?raw=true
#
# ###Response:
# ['Thereisnoevidenceoffractureorbonyabnormalities..Normalsofttissuedensities..WristXrayisNormal']
# https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0198_0798640498_01_WRI-L2_M011.png?raw=true
#
# The above example is a simple example of a conversation between two people. The first person is asking the second person to do something. The second person is responding to the first person. The first person is asking the second person to do something. The second person is responding to the first person. The first person is asking the second person to do something. The second person is responding to the first person. The first person
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)

# %%
prompt=["<s> Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.\n### Instruction: Based on the analysis of Wrist Xray, the following issues have been identified:\n### Input: ['pronatorsign', 'fracture', 'Left'] https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0015_0668695209_01_WRI-L2_F008.png?raw=true\n### Response:"]
do_inference(model,processor,prompt)
# Out:
#  Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.
# ### Instruction: Based on the analysis of Wrist Xray, the following issues have been identified:
# ### Input: ['pronatorsign', 'fracture', 'Left'] https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0015_0668695209_01_WRI-L2_F008.png?raw=true
# ### Response: The patient has a fracture of the left wrist.
#
# The patient has a fracture of the left wrist.
#
# The patient has a fracture of the left wrist.
#
# The patient has a fracture of the left wrist.
#
# The patient has a fracture of the left wrist.
#
# The patient has a fracture of the left wrist.
#
# The patient has a fracture of the left wrist.
#
# The patient has a fracture of the left wrist.
#
# The patient has a fracture of the left wrist.
#
# The patient has a fracture of the left wrist.
# " Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.\n### Instruction: Based on the analysis of Wrist Xray, the following issues have been identified:\n### Input: ['pronatorsign', 'fracture', 'Left'] https://github.com/GoutamSachdev/ReportDataSet/blob/main/Match_fracture/0015_0668695209_01_WRI-L2_F008.png?raw=true\n### Response: The patient has a fracture of the left wrist.\n\nThe patient has a fracture of the left wrist.\n\nThe patient has a fracture of the left wrist.\n\nThe patient has a fracture of the left wrist.\n\nThe patient has a fracture of the left wrist.\n\nThe patient has a fracture of the left wrist.\n\nThe patient has a fracture of the left wrist.\n\nThe patient has a fracture of the left wrist.\n\nThe patient has a fracture of the left wrist.\n\nThe patient has a fracture of the left wrist.\n\n"

# %%
print(f"ROUGE scores after training: {post_train_rouge}")
print(f"BLEU score after training: {post_train_bleu}")
# Out:
# ROUGE scores after training: {'rouge1': 0.3879891180953339, 'rouge2': 0.24752667049495905, 'rougeL': 0.29426126507146916}
# BLEU score after training: 0.00041132433587447116
